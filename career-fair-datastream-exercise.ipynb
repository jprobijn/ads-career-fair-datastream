# %%
# %matplotlib notebook
from modules.helper_functions import *

datastream = get_datastream()

# %% [markdown]
# ### The datastream
#
# We've gone ahead and created an example regular datastream which describes the positions of player positions in a football match over the course of 1 minute. Before we start doing some fun things with this datastream, let's first take a quick look at what kind of structure the incoming data will have.

# %%
datastream.get_data_sample()
# Out:
# {'Timestamp': '2019-03-11 18:52:43.807',
#  'pos': [{'PlrID': 0, 'TeamName': None, 'X': 0.1, 'Y': -0.5},
#   {'PlrID': 1, 'TeamName': 'Team 1', 'X': -45.288, 'Y': 0.081},
#   {'PlrID': 2, 'TeamName': 'Team 1', 'X': -22.264, 'Y': 4.956},
#   {'PlrID': 3, 'TeamName': 'Team 1', 'X': -18.049, 'Y': -5.535},
#   {'PlrID': 4, 'TeamName': 'Team 1', 'X': -17.186, 'Y': -13.983},
#   {'PlrID': 5, 'TeamName': 'Team 1', 'X': -8.339, 'Y': 14.777},
#   {'PlrID': 6, 'TeamName': 'Team 1', 'X': -8.617, 'Y': 1.012},
#   {'PlrID': 7, 'TeamName': 'Team 1', 'X': -8.322, 'Y': -5.579},
#   {'PlrID': 8, 'TeamName': 'Team 1', 'X': 0.168, 'Y': 1.282},
#   {'PlrID': 9, 'TeamName': 'Team 1', 'X': -7.276, 'Y': -26.741},
#   {'PlrID': 10, 'TeamName': 'Team 1', 'X': 0.337, 'Y': -1.216},
#   {'PlrID': 11, 'TeamName': 'Team 1', 'X': 0.344, 'Y': -11.243},
#   {'PlrID': 12, 'TeamName': 'Team 1', 'X': None, 'Y': None},
#   {'PlrID': 13, 'TeamName': 'Team 2', 'X': 50.209, 'Y': 0.118},
# ...

# %% [markdown]
# For those of you familiar with JSON, this should be easy enough to understand. You will get a message like this for every timepoint in the datastream. At the top level there's an object with 2 fields, *Timestamp* and *pos*.
#
# - *Timestamp* will contain a datetime string describing the exact time the measurements took place.
# - *pos* will contain an array of objects where each object has 4 fields describing a particular participant (player or ball) at that moment
#
# Every participant is described by an object containing several fields:
#
# - *PlrID* contains the unique identifier for that particular player, which is not going to change at any point in the datastream
# - *TeamName* contains a string describing the player's team. For the ball this will always be *None*
# - *X* contains the X-coordinate of the participant (position across the length of the field)
# - *Y* contains the Y-coordinate of the participant. (position across the width of the field)
#
# A little note on the coordinates: The center of the field is (0,0) and the X coordinates can vary from -52.5 to 52.5 while the Y coordinates can vary from -34 to 34.

# %% [markdown]
# ### The challenge
#
# Now that we've gone through some of the details of the incoming data, it's time for you to do something with it!
# Below there's a skeleton function simply called *func*. This function takes data for a particular timepoint in the datastream as input, as outlined above. Its' output has to be a list of player IDs that should be highlighted at that moment, given the input data.
#
# Write code into this function in such a way that the player closest to the ball is highlighted at that particular moment. You can simply execute and rerun the cell on demand to see an animation of the entire 1 minute datastream with the output of your function being used to highlight particular players at particular moments.

# %%
def func(data):
    
    # YOUR CODE GOES HERE
    x_ball = data['pos'][0]['X']
    y_ball = data['pos'][0]['Y']

    return [6, 11]

run_stream(datastream, func)
# Out:
# <img src="data:image/png;base64,..." width="900">
